# %% [markdown]
# <a href="https://colab.research.google.com/github/Anyerson1258/EA2---Scraping/blob/main/Velasquez_Anyerson_EA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# S30 - Evidencia de aprendizaje 1. Análisis y herramientas de extracción de datos
#
# ---
#
#
#
# ESTUDIANTE:
#
# Anyerson Felipe Velasquez Cardona
#
# DOCENTE:
#
# Andrés Felipe Palacio
#
#
# INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA
# Programación para Análisis de Datos
# 2024-2

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
import os

def scrape_mercadolibre(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, "html.parser")

        productos = soup.find_all("li", class_="ui-search-layout__item")

        resultados = ""
        for producto in productos:

            titulo_elemento = producto.find("h2", class_="ui-search-item__title")
            if not titulo_elemento:
                titulo_elemento = producto.find("h2")
            titulo = titulo_elemento.text.strip() if titulo_elemento else "Título no encontrado"

            precio_elemento = producto.find("div", class_="poly-price__current")
            if precio_elemento:
                precio = precio_elemento.find("span", class_="andes-money-amount__fraction").text.strip()
            else:
                precio = "Precio no encontrado"

            enlace_elemento = producto.find("a", class_="ui-search-item__group__element")
            if not enlace_elemento:
                enlace_elemento = producto.find("a", href=True)  # Intentar un selector más general
            enlace = enlace_elemento['href'].strip() if enlace_elemento else "Enlace no encontrado"

            resultados += f"Título: {titulo}\n"
            resultados += f"Precio: {precio}\n"
            resultados += f"Enlace: {enlace}\n"
            resultados += "-----\n"

        if not os.path.exists('/content/sample_data'):
            os.makedirs('/content/sample_data')
        with open("/content/sample_data/PPADD/mercadolibre_data.html", "w", encoding="utf-8") as f:
            f.write(str(soup))

        return resultados

    except requests.exceptions.RequestException as e:
        return f"Error al obtener la URL: {e}"
    except AttributeError as e:
        return f"Error al analizar el HTML: {e}. Verifica el selector CSS."
    except Exception as e:
        return f"Error inesperado: {e}"

url_mercadolibre = "https://listado.mercadolibre.com.co/sceptre-curvo-240hz"
resultados = scrape_mercadolibre(url_mercadolibre)
print(resultados)
# Out:
# Título: Monitor Sceptre C255b-fwt240, 24.5 PuLG, 240 Hz, Fhd, 1500r
# Precio: 885.872
# Enlace: https://articulo.mercadolibre.com.co/MCO-1940243660-monitor-sceptre-c255b-fwt240-245-pulg-240-hz-fhd-1500r-_JM#polycard_client=search-nordic&position=10&search_layout=stack&type=item&tracking_id=3ef9c617-22ab-4ee0-a0f4-840cbb7c5892
# -----
# Título: Monitor Sceptre u275w-upt 4k IPS 27'' UHD 70hz 99% RGB con Altavoces Integrados
# Precio: 1.255.900
# Enlace: https://www.mercadolibre.com.co/monitor-sceptre-u275w-upt-4k-ips-27-uhd-70hz-99-rgb-con-altavoces-integrados/p/MCO24252673#polycard_client=search-nordic&searchVariation=MCO24252673&position=2&search_layout=stack&type=product&tracking_id=3ef9c617-22ab-4ee0-a0f4-840cbb7c5892&wid=MCO2684418096&sid=search
# -----
# Título: Monitor gamer curvo Sceptre negro
# Precio: 1.146.900
# ...

# %%
# !git clone https://github.com/Anyerson1258/EA2---Scraping.git
# Out:
# Cloning into 'EA2---Scraping'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 14 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 18.37 KiB | 3.06 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# S30 - Evidencia de aprendizaje 2. Optimizando la productividad en el mundo del software
#
# ---
#
#
#
# ESTUDIANTE:
#
# Anyerson Felipe Velasquez Cardona
#
# DOCENTE:
#
# Andrés Felipe Palacio
#
#
# INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA
# Programación para Análisis de Datos
# 2024-2

# %% [markdown]
# # Introduccion
#
#
# En este proyecto, utilizamos scraping web para obtener datos de productos de MercadoLibre. El objetivo es analizar precios, títulos y enlaces de monitores, lo que permitirá realizar comparaciones de mercado y tomar decisiones informadas. Además, gestionamos el proyecto utilizando Git y GitHub para el control de versiones y la colaboración, asegurando un desarrollo organizado y eficiente.
#
# # Metodología
#
# ##Herramientas:
#
# *   Python con las librerías requests y BeautifulSoup.
# *   GitHub para el control de versiones y la colaboración.
#
#
# ###Proceso:
#
#
#
# *   Extracción del HTML: Usando requests.
# *   Análisis y Extracción: Usando BeautifulSoup para obtener títulos, precios y sobre el ultimo cambio realiza que se agrego los enlaces de cada producto.
# * Control de Versiones: Uso de Git para gestionar los cambios en el código y GitHub para la colaboración en equipo.
#
# # Resultados y Conclusiones
#
# Se extrajeron correctamente los títulos y precios de los productos, así como los enlaces. Los datos obtenidos permiten realizar análisis de mercado precisos y actualizados, aunque se requiere ajustar continuamente los selectores CSS debido a cambios en la estructura del sitio web.
#
# En resumen, el scraping web ha demostrado ser una herramienta eficaz para extraer datos relevantes directamente de las fuentes en línea, y el uso de GitHub ha permitido una gestión eficiente del proyecto, mejorando la colaboración y la calidad del desarrollo.
